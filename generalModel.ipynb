# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Conv2d
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class IVSN(nn.Module):
  def __init__(self, model):
      super(IVSN, self).__init__()
      self.features = nn.Sequential(*list(model.children())[0][:30])
      for param in self.features.parameters():
        param.requires_grad_ = False

  def forward(self, x):
      x = self.features(x)
      return x

ConvSize, NumTemplates, Mylayer = 1, 512, 31
MMconv = Conv2d(NumTemplates, 1, kernel_size = (ConvSize, ConvSize), stride = (1, 1), padding = (1, 1))
# 512 input channels, 1 output channel, 1x1 kernel, stride 1, padding 1

# %%
from torchvision.models import VGG16_Weights

model_vgg = torch.hub.load('pytorch/vision:v0.10.0', 'vgg16', weights=VGG16_Weights.DEFAULT)
model_ivsn = IVSN(model_vgg)
# Out:
# Using cache found in /Users/ishaan/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
import coco18datasets

data = coco18datasets.COCO_TADataset(normalize = True)

# %%
'''
# show image and print data of first element of daa
import matplotlib.pyplot as plt

print(len(data))
img, target, results = data[0]
print(results)
plt.imshow(img.permute(1, 2, 0))
plt.show()
plt.imshow(target.permute(1, 2, 0))
'''
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# 2572
# {'name': '000000538422.jpg', 'subject': 9, 'task': 'microwave', 'condition': 'absent', 'X': [814.9, 1299.6, 1436.3, 1418.1, 357.7], 'Y': [472.4, 478.2, 199.6, 74.3, 498.5], 'T': [273, 232, 92, 165, 325], 'length': 5, 'fixOnTarget': False, 'correct': 1, 'split': 'train'}

# %%
import torch
from tqdm import trange
from utilsTA import naturalSearchProcesswithPathFixedN, naturalSearchProcesswithPathNaiveEvidenceAccumulation
from utilsTA import naturalSearchProcesswithEdgeDensity, naturalSearchProcesswithPathNaiveGaussian
import matplotlib.pyplot as plt
import numpy as np
from torchvision import transforms
import pandas as pd

num_pics = len(data)

df_results = pd.DataFrame(columns=['image_id', 'true_count', 'fixedN_count', 'naive_evidence_accumulation_count', 'edge_density_count', 'naive_gaussian_count'])

with torch.no_grad():
    for id in range(num_pics):
        stimuli_img, target_img, info = data[id]
        #Need 3 channels:
        if stimuli_img.shape[0] == 1:
            stimuli_img = torch.cat((stimuli_img, stimuli_img, stimuli_img), 0)
        if target_img.shape[0] == 1:
            target_img = torch.cat((target_img, target_img, target_img), 0)
                
        stimuli_batch = stimuli_img.unsqueeze(0)
        target_batch = target_img.unsqueeze(0) 
        
        # Get the output from the model after going through all 30 layers
        stimuli_output = model_ivsn(stimuli_batch)
        target_output = model_ivsn(target_batch)
        
        # Update MMconv weights with target output
        MMconv.weight = torch.nn.Parameter(target_output)
        
        # Get the attention map by applying MMconv to stimuli_output
        attention_IVSN = MMconv(stimuli_output) 
        attention_IVSN = attention_IVSN.squeeze(0)
                
        # Normalize the attention map
        mask_IVSN = transforms.Resize((stimuli_img.shape[1], stimuli_img.shape[2]))(attention_IVSN)
        mask_IVSN = mask_IVSN.squeeze(0)
        mask_IVSN = torch.divide(mask_IVSN, mask_IVSN.max())
                        
        # Get the results from the natural search process
        resultFixedN, _, _ = naturalSearchProcesswithPathFixedN(mask_IVSN, 20)
        resultNaiveEvidenceAccumulation, _, _ = naturalSearchProcesswithPathNaiveEvidenceAccumulation(mask_IVSN, 1.0)
        resultEdgeDensity, _, _ = naturalSearchProcesswithEdgeDensity(mask_IVSN, stimuli_img)
        resultNaiveGaussian, _, _ = naturalSearchProcesswithPathNaiveGaussian(mask_IVSN, 10, 5)

        # Get the true count
        true_count = info['length']
        img_name = info['name']
        img_task = info['task']

        #add results to the dataframe
        new_row = pd.DataFrame([{
        'image_id': img_name,
        'true_count': true_count,
        'fixedN_count': resultFixedN,
        'naive_evidence_accumulation_count': resultNaiveEvidenceAccumulation,
        'edge_density_count': resultEdgeDensity,
        'naive_gaussian_count': resultNaiveGaussian
        }])

        df_results = pd.concat([df_results, new_row], ignore_index=True)
        print(f'Image {id+1} done') #about 2500 of them

        if id % 100 == 0:
            df_results.to_csv('TA_results_2_19_part2.csv', index=False)
# Out:
# /Users/ishaan/miniconda3/envs/VisualSearch/lib/python3.11/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Original img shape: (3, 1050, 1680)
# Original img dtype: float32
# Processed img shape: (1050, 1680)
# Processed img dtype: uint8
# Image 1 done
# Original img shape: (3, 1050, 1680)
# Original img dtype: float32
# ...

# %%
#read data and plot it

df_results = pd.read_csv('TA_results_2_19.csv')

# Calculate the mean absolute error for each method

df_results['fixedN_error'] = abs(df_results['true_count'] - df_results['fixedN_count'])
df_results['naive_evidence_accumulation_error'] = abs(df_results['true_count'] - df_results['naive_evidence_accumulation_count'])
df_results['edge_density_error'] = abs(df_results['true_count'] - df_results['edge_density_count'])
df_results['naive_gaussian_error'] = abs(df_results['true_count'] - df_results['naive_gaussian_count'])

mean_fixedN_error = df_results['fixedN_error'].mean()
mean_naive_evidence_accumulation_error = df_results['naive_evidence_accumulation_error'].mean()
mean_edge_density_error = df_results['edge_density_error'].mean()
mean_naive_gaussian_error = df_results['naive_gaussian_error'].mean()

print(f'Mean absolute error for fixed N: {mean_fixedN_error}')
print(f'Mean absolute error for naive evidence accumulation: {mean_naive_evidence_accumulation_error}')
print(f'Mean absolute error for edge density: {mean_edge_density_error}')
print(f'Mean absolute error for naive gaussian: {mean_naive_gaussian_error}')
# Out:
# Mean absolute error for fixed N: 12.112
# Mean absolute error for naive evidence accumulation: 6.18
# Mean absolute error for edge density: 6.336
# Mean absolute error for naive gaussian: 5.844

# %%
#plot the results with true value as x var and the predicted value as y var, for each averaging the results
df = pd.read_csv('TA_results_2_19.csv')
df.drop('image_id', axis=1, inplace=True)

df = df.groupby('true_count').mean().reset_index()
#plot the results

plt.figure(figsize=(10, 6))
plt.plot(df['true_count'], df['fixedN_count'], label='Fixed N')
plt.plot(df['true_count'], df['naive_evidence_accumulation_count'], label='Naive Evidence Accumulation')
plt.plot(df['true_count'], df['edge_density_count'], label='Edge Density')
plt.plot(df['true_count'], df['naive_gaussian_count'], label='Naive Gaussian')
plt.plot(df['true_count'], df['true_count'], 'k--', label='True Count')
plt.xlabel('True Count')
plt.ylabel('Predicted Count')
plt.legend()

# %%
#barchart of true count

df = pd.read_csv('TA_results_2_19.csv')
plt.figure(figsize=(10, 6))
df['true_count'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('True Count')
plt.ylabel('Number of Images')
plt.title('Distribution of True Counts in the Dataset')
# Out:
# Text(0.5, 1.0, 'Distribution of True Counts in the Dataset')

# %%
##maxwell boltzmann distribution?
